# %% [markdown]
# # Network Based Social Media Analytics
# ### Q Smart 2306288s
# #### Github: https://github.com/axqs/web_sci_ae
#
# Code in the next cell is taken from John H. Williamson's lecture notes for Data Fundamentals 2019
#
# ### Contents
# 1. [Introduction](#intro)
# 1. [Data Crawl](#data_crawl)
#   1. [Streaming](#stream)
#   1. [REST Probing](#rest)
# 1. [Group Tweets](#grouping)
# 1. [Capture and Organize User and Hashtag Information](#organize)
# 1. [Network Analysis](#analysis)

# %%
import IPython.display
IPython.display.HTML("""
    <script>
      function code_toggle() {
        if (code_shown){
          $('div.input').hide('500');
          $('#toggleButton').val('Show Code')
        } else {
          $('div.input').show('500');
          $('#toggleButton').val('Hide Code')
        }
        code_shown = !code_shown
      }

      $( document ).ready(function(){
        code_shown=false;
        $('div.input').hide()
      });
    </script>
    <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
""")

# %%
import pymongo
import tweepy
import os
import time

#mongodb access
password = os.environ["WEBSCI_MONGODB_PASS"]
client = pymongo.MongoClient("mongodb://qsmart:"+password+"@qs-web-science-ae-shard-00-00-4pdo2.mongodb.net:27017,qs-web-science-ae-shard-00-01-4pdo2.mongodb.net:27017,qs-web-science-ae-shard-00-02-4pdo2.mongodb.net:27017/test?ssl=true&replicaSet=qs-web-science-ae-shard-0&authSource=admin&retryWrites=true&w=majority")

#tweepy access
pk = os.environ["WEBSCI_PKEY"]
sk = os.environ["WEBSCI_SKEY"]
pt = os.environ["WEBSCI_PTOKEN"]
st = os.environ["WEBSCI_STOKEN"]

auth = tweepy.OAuthHandler(pk, sk)
auth.set_access_token(pt, st)

api = tweepy.API(auth)

print("Everything imported OK.")
# Out:
# Everything imported OK.

# %% [markdown]
# <a id="intro"></a>
# ## Introduction
# 1. Describe the software developed with appropriate details; if you have used code from elsewhere please specify it
# 2. Specify the time and duration of data collected
#
# # Tweepy
# ### Streaming is push of data by Twitter, Search is pull of data initiated by the end user.
# * one percent is from 1 hour stream, get additional data from rest probing
# * put sample data in csv (100 rows)
# * bad clusters expected, around 10, isolate noisy data -- smaller clusters can be ignored (2 ish docs)
# * stats: duration (ie for 10 clusters run for 1 hour, 6 min duration for groups), how many docs, num likes, num retweets, # hashtags, # users
# * tells tats of all clusters, only save valid ones
# * report on how much data from stream, and how much from rest
# * NO GRAPHS
# * tweets: only care about tweet id, date created, username, text
# * task 3: num users, top users and # connections
# #### How to cluster
# * scikit to cluster
# * remove retweets to cluster - explain why
# #### Part 3 Report
# * can draw graph of cluster sizes
# * summarize across all clusters, then elaborate with certain clusters
# #### Part 4&5 report
# * two groups, average all in each group, (stream and rest)

# %%
#neatly prints a dictionary object
def pretty_print(d, indent=0):
    for key,value in d.items():
        # print the indent, and then the key
        print(" "*indent,key,":", end=' ')

        # check if it's a dictionary: if so, recursive call
        if type(value)==type({}):
            print()
            pretty_print(value, indent+4)

        # if it's a list, print a comma separated sequence
        elif type(value)==type([]):
            print(", ".join(str(x) for x in value))
        else:
            # just a plain value
            print(value)

# %%
def filter_user_info(dictionary):
    #if user already exists in dictionary
    try:
        user_ids[dictionary["screen_name"]]["count"] += 1
    #if user does not exist
    except KeyError:
        tweet_user = {}
        # list to filter relevant user information
        user_info = ["name","screen_name","verified","location",
                     "followers_count","friends_count","favourites_count"]
        for j in user_info:
            tweet_user[j] = dictionary[j]
        tweet_user["count"] = 1
        #add new user to dictionary
        user_ids[dictionary["screen_name"]] = tweet_user
    # returns screen name of user
    return dictionary["screen_name"]

# %%
def filter_tweet_info(dictionary):
    filtered_info = {}
    # list to filter relevant user information
    tweet_info = ["created_at","user",
                  "extended_tweet","hashtags",
                  "in_reply_to_screen_name","retweeted_status",
                  "is_quote_status",
                  "retweet_count","favorite_count","quote_count","reply_count",]
    for j in tweet_info:
        if(j == "user"):
            filtered_info[j] = filter_user_info(dictionary["user"])
        else:
            try:
                # if "extended_tweet in dictionary, get full text. otherwise, get regular text"
                if j == "extended_tweet":
                    try:
                        filtered_info["text"] = dictionary[j]["full_text"]
                    except KeyError:
                        filtered_info["text"] = dictionary["text"]
                        
                # if tweet is a retweet, get the id of the retweeted tweet
                elif j == "retweeted_status":
                    try:
                        filtered_info["retweeted_status"] = dictionary["retweeted_status"]["screen_name"]
                        try:
                            filtered_info["text"] = dictionary["retweeted_status"]["extended_tweet"]["full_text"]
                        except:
                            filtered_info["text"] = dictionary["retweeted_status"]["text"]
                    except KeyError:
                        filtered_info["retweeted_status"] = False

                # get all hashtags in tweet 
                elif j == "hashtags":
                    filtered_info["hashtags"] = []
                    for h in dictionary["entities"]["hashtags"]:
                        filtered_info["hashtags"].append(h["text"])
                else:
                    filtered_info[j] = dictionary[j]
            except KeyError:
                filtered_info[j] = 0
    # returns dictionary of filtered tweet information
    return filtered_info

# %% [markdown]
# <a id="data_crawl"></a>
# ## Data Crawl
#
# 1. Use Twitter Streaming API for collecting 1% data
#   * Specify the APIs used
#     1. Please do not include entire code here; just main description of the function
#     2. Along with a short description/justification
# 2. Enhance the crawling using the hybrid architecture of Twitter Streaming & REST
# APIs
#   * Specify the APIs used
#     1. Please do not include entire code here; just main description of the function. Please describe how you developed a hybrid crawler.
#     2. Along with a short description/justification

# %% [markdown]
# <a id="stream"></a>
# ### Twitter Streaming

# %%
from datetime import datetime
from IPython.display import clear_output

#run stream for an hour
def streamTimer():
    currentTime = time.time()
    #check to see if hour has passed, 3600 seconds = 1 hr
    if(currentTime - startTime >= 2400):
        clear_output()
        print("Tracking: "+str(tracking))
        print("Stream started at: ",startStream)
        print("Collected:",len(streamed_tweets))
        print("Stream ended at: ",datetime.now().strftime("%m/%d/%Y, %H:%M:%S"))
        print("Disconnecting stream . . .")
        stream.disconnect()
        print("Stream disconnected.")
        
# for each tweet in the stream, add it to the streamed_tweets dictionary
class TwitterStreamer(tweepy.StreamListener):
    def on_status(self, status):
        print(status)
        streamed_tweets[status._json["id"]] = filter_tweet_info(status._json)
        print("-"*100,"Collected:",len(streamed_tweets))
        streamTimer()
        
    def on_error(self,status_code):
        print(status_code)
        return False

# %%
streamed_tweets = {}
user_ids = {}
# create listener
listener = TwitterStreamer(api=tweepy.API(auth,
                           wait_on_rate_limit=True, 
                           wait_on_rate_limit_notify=True))
# create streamer
stream = tweepy.Stream(auth=auth, listener=listener)

# words to look for and track in tweets
tracking = [
    "baseball","mlb","Major","League","Baseball",
    "world","series","spring","training","opening","day",
    "yankees","astros","dodgers","la","angels","chicago","cubs","tb","rays","red","sox",
    "cheated","scandal","houston","asterisks","sign","stealing","cheating",
    "astroscheated","astrosscandal","houstonasterisks","astroscheatingscandal",
]

print("Tracking: "+str(tracking))
# start timer for stream
startTime = time.time()
startStream = datetime.now().strftime("%m/%d/%Y, %H:%M:%S")
print("Stream started at: ",startStream)
# filter stream
stream.filter(track=tracking, languages=['en'], is_async=True)
# Out:
# Tracking: ['baseball', 'mlb', 'Major', 'League', 'Baseball', 'world', 'series', 'spring', 'training', 'opening', 'day', 'yankees', 'astros', 'dodgers', 'la', 'angels', 'chicago', 'cubs', 'tb', 'rays', 'red', 'sox', 'cheated', 'scandal', 'houston', 'asterisks', 'sign', 'stealing', 'cheating', 'astroscheated', 'astrosscandal', 'houstonasterisks', 'astroscheatingscandal']
# Stream started at:  03/07/2020, 14:46:35
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211287625735, 'id_str': '1236302211287625735', 'text': 'Imagine! 🖤', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 626453096, 'id_str': '626453096', 'name': 'Michael Francis Williams', 'screen_name': 'parleyment', 'location': 'Los Angeles, CA', 'url': 'https://www.instagram.com/mw1ll1ams/', 'description': 'director/artist  #davidmakesman https://vimeo.com/user19749684 http://www.michaelwilliams.work https://www.imdb.com/name/nm7694956/?ref_=rvi_nm', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 666, 'friends_count': 735, 'listed_count': 12, 'favourites_count': 27939, 'statuses_count': 8098, 'created_at': 'Wed Jul 04 13:19:57 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1230311577313665025/cRqNH1vN_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1230311577313665025/cRqNH1vN_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/626453096/1582163875', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '3b77caf94bfc81fe', 'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json', 'place_type': 'city', 'name': 'Los Angeles', 'full_name': 'Los Angeles, CA', 'country_code': 'US', 'country': 'United States', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-118.668404, 33.704538], [-118.668404, 34.337041], [-118.155409, 34.337041], [-118.155409, 33.704538]]]}, 'attributes': {}}, 'contributors': None, 'quoted_status_id': 1236297361950990337, 'quoted_status_id_str': '1236297361950990337', 'quoted_status': {'created_at': 'Sat Mar 07 14:27:15 +0000 2020', 'id': 1236297361950990337, 'id_str': '1236297361950990337', 'text': "Ernie Isley's birthday is today. ❤️\n\nI don't care what ANYONE says... He was/is the best part of The Isley Brothers… https://t.co/6iQWiczQY6", 'display_text_range': [0, 140], 'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 155700400, 'id_str': '155700400', 'name': 'Eric M. Black', 'screen_name': 'eb4prez', 'location': 'BROOKLYN, NEW YORK', 'url': 'http://www.facebook.com/eb4prez', 'description': 'Soul music cognoscente. Chicken wing connoisseur. Sci-fi enthusiast. Soul Brother Number Two. Mr. #TurnThisUp!!! Orange Moon from the Otherside of the Game', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 5644, 'friends_count': 1241, 'listed_count': 156, 'favourites_count': 15816, 'statuses_count': 300738, 'created_at': 'Mon Jun 14 21:36:17 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1 ...
# ---------------------------------------------------------------------------------------------------- Collected: 1
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211430440960, 'id_str': '1236302211430440960', 'text': 'RT @ZAbbasOfficial: Seems like a test match day 4 pitch! 😬😂 #LQVQG', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1234208079438393345, 'id_str': '1234208079438393345', 'name': 'Subhan', 'screen_name': '_ssubban', 'location': 'کراچی, پاکستان', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 0, 'friends_count': 138, 'listed_count': 0, 'favourites_count': 17, 'statuses_count': 10, 'created_at': 'Sun Mar 01 20:05:20 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1234208936900911106/ZsaogDq2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1234208936900911106/ZsaogDq2_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 14:35:32 +0000 2020', 'id': 1236299449871335424, 'id_str': '1236299449871335424', 'text': 'Seems like a test match day 4 pitch! 😬😂 #LQVQG', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 333800185, 'id_str': '333800185', 'name': 'zainab abbas', 'screen_name': 'ZAbbasOfficial', 'location': None, 'url': 'https://Instagram.com/zabbasofficial/', 'description': 'Presenter for ICC Cricket World Cup 2019,Pakistan Super League,T10,Cricingif,Ten Sports & Sony,occasional writer for Dawn. Worked with Dunya News', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 1660104, 'friends_count': 1136, 'listed_count': 449, 'favourites_count': 9224, 'statuses_count': 20090, 'created_at': 'Tue Jul 12 03:15:51 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1231179218597433345/OmgNmbJ__normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1231179218597433345/OmgNmbJ__normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/333800185/1498070685', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 6, 'reply_count': 39, 'retweet_count': 59, 'favorite_count': 695, 'entities' ...
# ---------------------------------------------------------------------------------------------------- Collected: 2
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211430240256, 'id_str': '1236302211430240256', 'text': "RT @earthshakerph: BREAKING: The Department of Health (DOH) already placed the country's #COVID19 Alert to CODE RED as of this afternoon.…", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 85978995, 'id_str': '85978995', 'name': 'klay', 'screen_name': 'ye__e_e', 'location': None, 'url': None, 'description': '6/16', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2243, 'friends_count': 130, 'listed_count': 15, 'favourites_count': 8063, 'statuses_count': 34834, 'created_at': 'Thu Oct 29 02:49:40 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'FFF04D', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'FAB81E', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1234872187909074944/r6XmelfM_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1234872187909074944/r6XmelfM_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/85978995/1580814764', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 06:02:09 +0000 2020', 'id': 1236170249466077186, 'id_str': '1236170249466077186', 'text': "BREAKING: The Department of Health (DOH) already placed the country's #COVID19 Alert to CODE RED as of this afterno… https://t.co/TFle4YresR", 'display_text_range': [0, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1079160267093635072, 'id_str': '1079160267093635072', 'name': 'EarthShakerPH', 'screen_name': 'earthshakerph', 'location': None, 'url': None, 'description': 'Earth Shaker is an organization which aims to shake the appreciation of Earth Sciences in the society and empower citizens to have science-based decisions.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 34096, 'friends_count': 14, 'listed_count': 63, 'favourites_count': 2069, 'statuses_count': 4663, 'created_at': 'Sat Dec 29 23:40:32 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1079160420546428928/W9yPsS_5_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1079160420546428928/W9yPsS_5_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1079160267093635072/1578312620', 'default_profile': True, 'default_profile_image': False, 'following': Non ...
# ---------------------------------------------------------------------------------------------------- Collected: 3
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211388444672, 'id_str': '1236302211388444672', 'text': 'RT @zhinuksunshine: Perfect! They went Against most positive fandom just because she didn’t shame Sana like them🙂 \nBut now they all hypocri…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1212967723954606080, 'id_str': '1212967723954606080', 'name': 'preetsidhu', 'screen_name': 'preetsi62368786', 'location': 'Punjab, India', 'url': None, 'description': 'Loves to travel, wifey and mommy !!', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 65, 'friends_count': 66, 'listed_count': 0, 'favourites_count': 20466, 'statuses_count': 24663, 'created_at': 'Fri Jan 03 05:23:55 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1232405581798965249/1SSZCfAd_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1232405581798965249/1SSZCfAd_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 14:38:55 +0000 2020', 'id': 1236300298974457856, 'id_str': '1236300298974457856', 'text': 'Perfect! They went Against most positive fandom just because she didn’t shame Sana like them🙂 \nBut now they all hyp… https://t.co/Tl46pl0TvJ', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1203967890174570499, 'id_str': '1203967890174570499', 'name': '💫', 'screen_name': 'zhinuksunshine', 'location': None, 'url': None, 'description': 'Mysterious', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1430, 'friends_count': 287, 'listed_count': 0, 'favourites_count': 25607, 'statuses_count': 9401, 'created_at': 'Mon Dec 09 09:22:00 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1233648746430267393/pduxVqjG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1233648746430267393/pduxVqjG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1203967890174570499/1583464795', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1236298864551854080, 'quoted_status_id_str': '1236298864551854080', 'quoted_status': {'created_at': 'Sat Mar 07 14:33:13 +0000 2020 ...
# ---------------------------------------------------------------------------------------------------- Collected: 4
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211065487368, 'id_str': '1236302211065487368', 'text': '@FTLCityNews @BrittanyWallman @BrowardCounty @DeanTrantalis @heathermoraitis @glassman4ftl @rmckinzie8779… https://t.co/soEG5ApLQ2', 'display_text_range': [117, 140], 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': 1236062018098130944, 'in_reply_to_status_id_str': '1236062018098130944', 'in_reply_to_user_id': 1134985088, 'in_reply_to_user_id_str': '1134985088', 'in_reply_to_screen_name': 'FTLCityNews', 'user': {'id': 919941659781148672, 'id_str': '919941659781148672', 'name': 'Cy.Activist R.Walsh', 'screen_name': 'ActivistRobert', 'location': 'Fort lauderdale', 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 14, 'friends_count': 29, 'listed_count': 0, 'favourites_count': 1688, 'statuses_count': 253, 'created_at': 'Mon Oct 16 15:02:38 +0000 2017', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': "@FTLCityNews @BrittanyWallman @BrowardCounty @DeanTrantalis @heathermoraitis @glassman4ftl @rmckinzie8779 @BenSorensen @clagerbloom @playlauderdale @FLPD411 @FLFR411 @CFLCA2018 There r 2 cases now in Broward.I would cancel next Saturday At Patrick's day festivals on March 14.", 'display_text_range': [177, 276], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'FTLCityNews', 'name': 'City of Fort Lauderdale', 'id': 1134985088, 'id_str': '1134985088', 'indices': [0, 12]}, {'screen_name': 'BrittanyWallman', 'name': 'Brittany Wallman', 'id': 20316308, 'id_str': '20316308', 'indices': [13, 29]}, {'screen_name': 'BrowardCounty', 'name': 'Broward County Government', 'id': 2174077896, 'id_str': '2174077896', 'indices': [30, 44]}, {'screen_name': 'DeanTrantalis', 'name': 'Dean Trantalis', 'id': 978478683412418565, 'id_str': '978478683412418565', 'indices': [45, 59]}, {'screen_name': 'heathermoraitis', 'name': 'heather moraitis', 'id': 57189631, 'id_str': '57189631', 'indices': [60, 76]}, {'screen_name': 'glassman4ftl', 'name': 'Steve Glassman', 'id': 958404225570103296, 'id_str': '958404225570103296', 'indices': [77, 90]}, {'screen_name': 'rmckinzie8779', 'name': 'Robert Mckinzie', 'id': 3337942949, 'id_str': '3337942949', 'indices': [91, 105]}, {'screen_name': 'BenSorensen', 'name': 'Ben Sorensen', 'id': 22019123, 'id_str': '22019123', 'indices': [106, 118]}, {'screen_name': 'clagerbloom', 'name': 'Chris Lagerbloom', 'id': 375710450, 'id_str': '375710450', 'indices': [119, 131]}, {'screen_name': 'playlauderdale', 'name': 'FortLauderdaleParks', 'id': 350920075, 'id_str': '350920075', 'indices': [132, 147]}, {'screen_name': 'FLPD411', 'name': 'Fort Lauderdale PD', 'id': 382235939, 'id_str': '382235939', 'indices': [148, 156]}, {'screen_name': 'FLFR411', 'name': 'FLFR PIO', 'id': 2451759518, 'id_str': '2451759518', 'indices': [157, 165]}, {'screen_name': 'CFLCA2018', 'name': 'Council of Fort Lauderdale Civic Associations', 'id': 947 ...
# ---------------------------------------------------------------------------------------------------- Collected: 5
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211644141568, 'id_str': '1236302211644141568', 'text': 'RT @nct127fess: (127) To all NCTzen around the world remember what Johnny said to us :\n"You guys, our NCTzens, are never alone! NCTzen have…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1186618521452601344, 'id_str': '1186618521452601344', 'name': 'Mbak saYang/ giveaway 📌', 'screen_name': 'yayangnyangyang', 'location': None, 'url': 'http://bit.ly/37jw3ld', 'description': 'mau punya anak namanya eleven dan pinter nari -liu yangyang', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1322, 'friends_count': 1075, 'listed_count': 0, 'favourites_count': 367, 'statuses_count': 14276, 'created_at': 'Tue Oct 22 12:21:24 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211328314096283649/pyJyHF1Q_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211328314096283649/pyJyHF1Q_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1186618521452601344/1572739283', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 14:45:15 +0000 2020', 'id': 1236301895506919429, 'id_str': '1236301895506919429', 'text': '(127) To all NCTzen around the world remember what Johnny said to us :\n"You guys, our NCTzens, are never alone! NCT… https://t.co/BLdKpCiokI', 'display_text_range': [0, 140], 'source': '<a href="https://twitter.com/nct127fess" rel="nofollow">#KickItWithNCT127</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1154928849756364800, 'id_str': '1154928849756364800', 'name': '(127)', 'screen_name': 'nct127fess', 'location': None, 'url': 'http://nct127fess.tumblr.com', 'description': 'an autobase for NCTzen 127 to talk and share all about @NCTsmtown_127 | use (127) to send DM | report: @i_li_chil', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 9143, 'friends_count': 571, 'listed_count': 85, 'favourites_count': 4, 'statuses_count': 3535, 'created_at': 'Sat Jul 27 01:37:50 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1225440608853979137/iWkmIX9z_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1225440608853979137/iWkmIX9z_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1154928849756364800/1580814412', 'default_profile': True, 'default_profile_image': False, ' ...
# ---------------------------------------------------------------------------------------------------- Collected: 6
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211547901953, 'id_str': '1236302211547901953', 'text': 'RT @CocoMo1211: @YasminYonis To be a dark skinned young lady in the world is a constant battle and struggle. Reminded me of myself as a you…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 508265087, 'id_str': '508265087', 'name': 'Mani🎀', 'screen_name': 'chocolattgaal', 'location': 'Minneapolis, MN', 'url': None, 'description': 'ig: @chocolattgaal', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1344, 'friends_count': 1310, 'listed_count': 11, 'favourites_count': 72132, 'statuses_count': 76304, 'created_at': 'Wed Feb 29 02:39:40 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_link_color': '009999', 'profile_sidebar_border_color': 'EEEEEE', 'profile_sidebar_fill_color': 'EFEFEF', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1223728925169397762/KFFPOtOM_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1223728925169397762/KFFPOtOM_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/508265087/1579212310', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 14:02:45 +0000 2020', 'id': 1236291198412783618, 'id_str': '1236291198412783618', 'text': '@YasminYonis To be a dark skinned young lady in the world is a constant battle and struggle. Reminded me of myself… https://t.co/tacgaJEftu', 'display_text_range': [13, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': 1235968309671194625, 'in_reply_to_status_id_str': '1235968309671194625', 'in_reply_to_user_id': 22591543, 'in_reply_to_user_id_str': '22591543', 'in_reply_to_screen_name': 'YasminYonis', 'user': {'id': 731444450585501699, 'id_str': '731444450585501699', 'name': 'Monéy', 'screen_name': 'CocoMo1211', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 197, 'friends_count': 487, 'listed_count': 0, 'favourites_count': 78200, 'statuses_count': 1670, 'created_at': 'Sat May 14 11:22:01 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1187629396817055744/K45AaTQt_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1187629396817055744/K45AaTQt_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/731444450585501699/1565123749', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': N ...
# ---------------------------------------------------------------------------------------------------- Collected: 7
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211610746888, 'id_str': '1236302211610746888', 'text': 'RT @lifeofrickey: HAVING A BAD DAY?? THEN THIS IS FOR YOU!!! https://t.co/jFPcRAbalr', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2272993522, 'id_str': '2272993522', 'name': 'Toni Marinaccio', 'screen_name': 'toni_marinaccio', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 358, 'friends_count': 362, 'listed_count': 4, 'favourites_count': 3870, 'statuses_count': 1844, 'created_at': 'Fri Jan 10 14:05:12 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1183818527255465989/mjM5kNwf_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183818527255465989/mjM5kNwf_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2272993522/1580194831', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 06 21:49:54 +0000 2020', 'id': 1236046372454817792, 'id_str': '1236046372454817792', 'text': 'HAVING A BAD DAY?? THEN THIS IS FOR YOU!!! https://t.co/jFPcRAbalr', 'display_text_range': [0, 42], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2316574530, 'id_str': '2316574530', 'name': 'RICK', 'screen_name': 'lifeofrickey', 'location': 'Los Angeles, CA', 'url': None, 'description': 'I like to make people laugh that’s all BOOKED&BUSY BABY! Inquiries:bookings@therickeythompson.com', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 859075, 'friends_count': 1762, 'listed_count': 1000, 'favourites_count': 9244, 'statuses_count': 6330, 'created_at': 'Wed Jan 29 05:39:52 +0000 2014', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '050505', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_link_color': '080808', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1201076408547782656/59yj7IZO_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201076408547782656/59yj7IZO_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2316574530/1576723801', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates' ...
# ---------------------------------------------------------------------------------------------------- Collected: 8
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211665313792, 'id_str': '1236302211665313792', 'text': 'RT @Kkmegan1: Me every day after March 20th: no one is home pls go away https://t.co/j5HQq4N168', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1229916225326723072, 'id_str': '1229916225326723072', 'name': 'Alfie', 'screen_name': 'alfiecrossing', 'location': None, 'url': None, 'description': 'Tigidy & megancrossing81 hate page', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2, 'friends_count': 5, 'listed_count': 0, 'favourites_count': 20, 'statuses_count': 4, 'created_at': 'Tue Feb 18 23:51:00 +0000 2020', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1229916427001483265/Wqp2pGbz_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1229916427001483265/Wqp2pGbz_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1229916225326723072/1582126018', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 06 19:50:01 +0000 2020', 'id': 1236016201404428293, 'id_str': '1236016201404428293', 'text': 'Me every day after March 20th: no one is home pls go away https://t.co/j5HQq4N168', 'display_text_range': [0, 57], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1114675421851811841, 'id_str': '1114675421851811841', 'name': 'Kkmegan', 'screen_name': 'Kkmegan1', 'location': None, 'url': None, 'description': 'professional clown over at https://www.twitch.tv/megancrossing81', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 250, 'friends_count': 67, 'listed_count': 0, 'favourites_count': 534, 'statuses_count': 640, 'created_at': 'Sat Apr 06 23:45:05 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1223441676884201472/Cpiz-GLZ_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1223441676884201472/Cpiz-GLZ_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1114675421851811841/1554602007', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 10, 'favorite_count': 58, 'entitie ...
# ---------------------------------------------------------------------------------------------------- Collected: 9
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211421962240, 'id_str': '1236302211421962240', 'text': "RT @WorldwideAFC: Liverpool (1) have lost more Premier League games this season than Arsenal's Invincibles (0).\n\n🙂", 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 728362903938674688, 'id_str': '728362903938674688', 'name': 'it be like that sometimes', 'screen_name': 'messyhairgurl', 'location': None, 'url': None, 'description': None, 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 262, 'friends_count': 475, 'listed_count': 7, 'favourites_count': 21767, 'statuses_count': 18207, 'created_at': 'Thu May 05 23:17:03 +0000 2016', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211126202590732291/QsyhzscM_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211126202590732291/QsyhzscM_normal.jpg', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Mar 07 14:37:28 +0000 2020', 'id': 1236299933382258689, 'id_str': '1236299933382258689', 'text': "Liverpool (1) have lost more Premier League games this season than Arsenal's Invincibles (0).\n\n🙂", 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 966817980423266304, 'id_str': '966817980423266304', 'name': 'WorldwideArsenal™', 'screen_name': 'WorldwideAFC', 'location': 'Worldwide', 'url': 'https://www.instagram.com/worldwideafc/', 'description': "All things Arsenal. Follow for updates. DM's are open. Follow @TH14Stuff", 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 27977, 'friends_count': 864, 'listed_count': 129, 'favourites_count': 25016, 'statuses_count': 4718, 'created_at': 'Thu Feb 22 23:32:23 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'E81C4F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1182401604106031109/QeekKUxS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1182401604106031109/QeekKUxS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/966817980423266304/1570741234', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'quoted_status_id': 1236297681582112768,  ...
# ---------------------------------------------------------------------------------------------------- Collected: 10
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:31 +0000 2020', 'id': 1236302211690500096, 'id_str': '1236302211690500096', 'text': 'RT @muyvva: Radio silence is apparently a necessity for the world’s largest fully steerable radio telescope. People live with no Wi-Fi, no…', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 203007837, 'id_str': '203007837', 'name': 'Philip Di Salvo', 'screen_name': 'philipdisalvo', 'location': 'Italia', 'url': 'http://usi.to/mhi', 'description': 'Post-doc @USI_university, lecturer @NabaMilano. Journalist. Hacking/journalism, leaks, data. My book: http://bit.ly/30kzXIc', 'translator_type': 'none', 'protected': False, 'verified': True, 'followers_count': 4330, 'friends_count': 2997, 'listed_count': 228, 'favourites_count': 8531, 'statuses_count': 20010, 'created_at': 'Fri Oct 15 09:44:56 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': False, 'profile_link_color': '778899', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/735458424767549449/ZpeaKkkS_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/735458424767549449/ZpeaKkkS_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/203007837/1398262048', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 06 22:01:27 +0000 2020', 'id': 1236049280563064835, 'id_str': '1236049280563064835', 'text': 'Radio silence is apparently a necessity for the world’s largest fully steerable radio telescope. People live with n… https://t.co/4cNO8j4cR8', 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 204050422, 'id_str': '204050422', 'name': 'Maria Rikitianskaia', 'screen_name': 'muyvva', 'location': 'London, United Kingdom', 'url': 'https://mrikitianskaia.com/', 'description': 'Postdoc, @MediaLSE and @usi_university. Media history, wireless networks, transnational approach', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 387, 'friends_count': 319, 'listed_count': 9, 'favourites_count': 472, 'statuses_count': 2079, 'created_at': 'Sun Oct 17 20:18:42 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'EBF0C9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': 'CAD19B', 'profile_sidebar_border_color': 'EBDEC5', 'profile_sidebar_fill_color': 'F5F1D0', 'profile_text_color': '5E3D1E', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1107757032638156800/xNN2kUAY_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107757032638156800/xN ...
# ---------------------------------------------------------------------------------------------------- Collected: 11
# ...
# ---------------------------------------------------------------------------------------------------- Collected: 87
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:32 +0000 2020', 'id': 1236302214936891393, 'id_str': '1236302214936891393', 'text': 'Check out 1984 Steve Yzerman RC PSA 8 NM-MT OPC Detroit Red Wings HOF #67 #DetroitRedWings https://t.co/n5IY3SYQA0 via @eBay', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20711567, 'id_str': '20711567', 'name': 'Nick Mattiacci', 'screen_name': 'Nickhockeycards', 'location': 'Canada', 'url': None, 'description': 'Check out my old hockey cards on http://eBay.com @ nickhockeycards', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1358, 'friends_count': 3663, 'listed_count': 13, 'favourites_count': 3831, 'statuses_count': 122699, 'created_at': 'Thu Feb 12 20:02:15 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '75D7D4', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '75D7D4', 'profile_sidebar_border_color': 'F9F74E', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '6ED492', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/945902442515968000/dSXk8_vN_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/945902442515968000/dSXk8_vN_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20711567/1487214753', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'DetroitRedWings', 'indices': [74, 90]}], 'urls': [{'url': 'https://t.co/n5IY3SYQA0', 'expanded_url': 'https://ebay.us/MeMDmZ', 'display_url': 'ebay.us/MeMDmZ', 'indices': [91, 114]}], 'user_mentions': [{'screen_name': 'eBay', 'name': 'eBay', 'id': 19709040, 'id_str': '19709040', 'indices': [119, 124]}], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'en', 'timestamp_ms': '1583592392082'}, created_at=datetime.datetime(2020, 3, 7, 14, 46, 32), id=1236302214936891393, id_str='1236302214936891393', text='Check out 1984 Steve Yzerman RC PSA 8 NM-MT OPC Detroit Red Wings HOF #67 #DetroitRedWings https://t.co/n5IY3SYQA0 via @eBay', source='Twitter Web Client', source_url='http://twitter.com', truncated=False, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x1288afd50>, _json={'id': 20711567, 'id_str': '20711567', 'name': 'Nick Mattiacci', 'screen_name': 'Nickhockeycards', 'location': 'Canada', 'url': None, 'description': 'Check out my old hockey cards on http://eBay.com @ nickhockeycards', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 1358, 'friends_count': 3663, 'listed_count': 13, 'favourites_count': 3831, 'statuses_count': 122699, 'created_at': 'Thu Feb 12 20:02:15 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '75D7D4', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'p ...
# ---------------------------------------------------------------------------------------------------- Collected: 88
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:32 +0000 2020', 'id': 1236302214907359233, 'id_str': '1236302214907359233', 'text': 'RT @_alicejay: did you guys camp out in front of a starbucks until asian people walked past the sign for this picture https://t.co/AXXHxzmk…', 'source': '<a href="http://tapbots.com/tweetbot" rel="nofollow">Tweetbot for iΟS</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 20348940, 'id_str': '20348940', 'name': 'Paul Togonon', 'screen_name': 'pgtogo84bsxy', 'location': 'SF Bay Area', 'url': None, 'description': 'If all you believe are headlines, you will never know the story.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 229, 'friends_count': 316, 'listed_count': 9, 'favourites_count': 2146, 'statuses_count': 13355, 'created_at': 'Sun Feb 08 03:22:07 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '022330', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png', 'profile_background_tile': False, 'profile_link_color': '3B94D9', 'profile_sidebar_border_color': 'A8C7F7', 'profile_sidebar_fill_color': 'C0DFEC', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1211683242295754752/BjkbO_-P_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211683242295754752/BjkbO_-P_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20348940/1569797990', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Thu Mar 05 23:40:57 +0000 2020', 'id': 1235711932839211009, 'id_str': '1235711932839211009', 'text': 'did you guys camp out in front of a starbucks until asian people walked past the sign for this picture https://t.co/AXXHxzmksK', 'display_text_range': [0, 102], 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 854101788, 'id_str': '854101788', 'name': 'a lice', 'screen_name': '_alicejay', 'location': 'Chicago, IL', 'url': 'http://instagram.com/_alicejay', 'description': 'tweetin. art page: @out_of_lines_', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 6276, 'friends_count': 386, 'listed_count': 10, 'favourites_count': 17218, 'statuses_count': 2071, 'created_at': 'Sun Sep 30 04:35:44 +0000 2012', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1236136410358390784/2R_hURJx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1236136410358390784/2R_hURJx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/854101788/1582610230', 'default_profile': True, 'defau ...
# ---------------------------------------------------------------------------------------------------- Collected: 89
# Status(_api=<tweepy.api.API object at 0x1288afd50>, _json={'created_at': 'Sat Mar 07 14:46:32 +0000 2020', 'id': 1236302214790078464, 'id_str': '1236302214790078464', 'text': 'RT @YasminYonis: I really appreciate how she attended to her pain, listened to her, affirmed her, took her seriously. Black children, espec…', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1167140216815181829, 'id_str': '1167140216815181829', 'name': '6..', 'screen_name': 'souitii', 'location': None, 'url': None, 'description': 'je t’aime grand comme ça \U0001f90f🏽', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 118, 'friends_count': 162, 'listed_count': 0, 'favourites_count': 15002, 'statuses_count': 19279, 'created_at': 'Thu Aug 29 18:21:34 +0000 2019', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1234805043393638400/N8oDsCLx_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1234805043393638400/N8oDsCLx_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1167140216815181829/1583529431', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Mar 06 16:39:42 +0000 2020', 'id': 1235968309671194625, 'id_str': '1235968309671194625', 'text': 'I really appreciate how she attended to her pain, listened to her, affirmed her, took her seriously. Black children… https://t.co/bb12Zz2dzv', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 22591543, 'id_str': '22591543', 'name': 'Your Woke Aunty', 'screen_name': 'YasminYonis', 'location': 'Arlington, VA', 'url': None, 'description': 'Somali born| Southern raised| Muslim| Womanist| MDiv ‘19 Social Ethics @UnionSeminary| Movement Chaplain| Network Facilitator| Inquires: YasminYonis@gmail.com', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 31469, 'friends_count': 1109, 'listed_count': 739, 'favourites_count': 69840, 'statuses_count': 75899, 'created_at': 'Tue Mar 03 05:42:00 +0000 2009', 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'DBE9ED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'CC3366', 'profile_sidebar_border_color': 'DBE9ED', 'profile_sidebar_fill_color': 'E6F6F9', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1215750075131092992/lDEbrC27_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1215750075131092992/lDEbrC27_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/22591543/1466900053', 'default_profile': False, 'default_profile_ ...
# ---------------------------------------------------------------------------------------------------- Collected: 90

# %%
stream.disconnect()

# %%
print("Tweets acquired by streaming:",len(streamed_tweets))
# Out:
# Tweets acquired by streaming: 119975

# %% [markdown]
# <a id="rest"></a>
# ### REST Probing

# %%
# get 1000 most recent tweets by user, given username/screen_name
def getTweetsByUsername(name):
    print(name,end=", ")
    timeline = tweepy.Cursor(api.user_timeline, screen_name=name, count=200, lang="en", include_rts=False, wait_on_rate_limit=True).items(1000)
    tweepy.Cursor(api.search, lang="en", count=100, until="").items(1000)
    for item in timeline:
        filter_tweet = filter_tweet_info(item._json)
        rest_tweets[item._json["id"]] = filter_tweet

# %%
# get all tweets in the past year that contain certain keywords
def getTweetsByKeywords(words):
    print("Getting tweets with:",end=" ")
    for word in words:
        print(word,end=", ")
        timeline = tweepy.Cursor(api.search, q=word, count=200, since="2019-03-06", until="2020-03-06", wait_on_rate_limit=True).items()
        for item in timeline:
            filter_tweet = filter_tweet_info(item._json)
            # add tweet to rest_tweets dictionary
            rest_tweets[item._json["id"]] = filter_tweet

# %%
keywords = ["#astroscheated","#astrosscandal","#houstonasterisks","#StripTheTitle","#TaintedTitle","AsteriskTour"]
mlb_official_accounts = ['BlueJaysPR', 'DetroitTigersPR', 'LAAngelsPR', 'MarinersPR', 'Rockies', 'RangerBlake', 
                         'whitesox', 'Phillies', 'Marlins', 'Indians', 'Cardinals', 'Brewers', 'astros', 'MLBPAA', 
                         'SFGiants', 'Mariners', 'BlueJays', 'Cubs', 'Rangers', 'Yankees', 'RedSox', 'MLB_PLAYERS', 
                         'RaysBaseball', 'Nationals', 'Twins', 'Angels', 'RockiesClubInfo', 'Orioles', 'Mets', 'MLB_PR', 
                         'Pirates', 'Padres', 'YankeesPR', 'Reds', 'Dbacks', 'tigers', 'MarlinsComms', 'Royals', 
                         'Dodgers', 'Braves', 'Athletics','MLB']
rest_tweets = {}
getTweetsByKeywords(keywords)
print("\nGetting tweets by:",end=" ")
for i in mlb_official_accounts:
    getTweetsByUsername(i)
print("\nDone.")
# Out:
# Getting tweets with: #astroscheated, #astrosscandal, #houstonasterisks, #StripTheTitle, #TaintedTitle, AsteriskTour,
# Getting tweets by: BlueJaysPR, DetroitTigersPR, LAAngelsPR, MarinersPR, Rockies, RangerBlake, whitesox, Phillies, Marlins, Indians, Cardinals, Brewers, astros, MLBPAA, SFGiants, Mariners, BlueJays, Cubs, Rangers, Yankees, RedSox, MLB_PLAYERS, RaysBaseball, Nationals, Twins, Angels, RockiesClubInfo, Orioles, Mets, MLB_PR, Pirates, Padres, YankeesPR, Reds, Dbacks, tigers, MarlinsComms, Royals, Dodgers, Braves, Athletics, MLB,
# Done.

# %%
print("Tweets found by REST probing:",len(rest_tweets))
# Out:
# Tweets found by REST probing: 117091

# %% [markdown]
# <a id="grouping"></a>
# ## Group Tweets
# 1. Describe your method for grouping & provide statistics on groups.
# 2. Describe the method for Username and Hashtag identification.
#   * Provide in a tabular fashion data statistics.
#   * Total data; groups; average size of a group; min size; max size etc.
#   * Provide data on a tabular fashion and contrast for entire data and just for grouped data.

# %%
def strip_documents(documents):
    filtered_documents = []
    # filter tweet text to remove any links and mentions before clustering
    for i in documents:
        split_words = i.strip().split()
        filtered_line = []
        for s in split_words:
            if "http" not in s and "@" not in s and "#" not in s:
                filtered_line.append(s)
        filtered_line = " ".join(filtered_line)
        filtered_documents.append(filtered_line)
    return filtered_documents

def filter_documents(docs):
    filtered_docs = []
    phrases = [
        "baseball","mlb","Major League Baseball",
        "world series","spring training","opening day",
        "yankees","astros","dodgers","los angeles angels","chicago cubs","tampa bay rays","red sox","la angels","tb rays",
        "astros cheated","astros scandal","houston asterisks","sign stealing","astros cheating scandal",
        "astroscheated","astrosscandal","houstonasterisks","astroscheatingscandal"
    ]
    for doc in docs:
        count = 0
        for p in phrases:
            if p.lower() in doc.lower():
                count += 1
        if count >= 1:
            filtered_docs.append(doc)
    return filtered_docs

# %%
import pandas as pd

users_df =  pd.DataFrame.from_dict(user_ids).T
streamed_df = pd.DataFrame.from_dict(streamed_tweets).T
rest_df = pd.DataFrame.from_dict(rest_tweets).T

documents = streamed_df["text"].tolist() + rest_df["text"].tolist()
documents = strip_documents(documents)
filtered = filter_documents(documents)
print(len(documents),"documents")
print(len(filtered),"filtered documents")
# Out:
# 237066 documents
# 28926 filtered documents

# %%
def cluster(text):
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(text)
    print(len(text))
    true_k = int(str(len(text))[:2])
    model = KMeans(n_clusters=true_k, init='k-means++', max_iter=1000, n_init=1)
    model.fit(X)

    print("Top terms per cluster:")
    order_centroids = model.cluster_centers_.argsort()[:, ::-1]
    terms = vectorizer.get_feature_names()
    for i in range(true_k):
        print ("Cluster %d:" % i)
        for ind in order_centroids[i, :10]:
            print(terms[ind],end=", ")
        print("\n")

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

cluster(filtered)
# Out:
# 28926
# Top terms per cluster:
# Cluster 0:
# combined, swing, miss, single, curveballs, sliders, kershaw, 51, 2017, world,
#
# Cluster 1:
# gonna, long, year, astros, rt, season, espera, esposito, espn, espinosa,
#
# Cluster 2:
# february, 26th, times, pitches, games, players, hit, astros, rt, championpicks,
#
# Cluster 3:
# right, getting, fans, training, spring, rt, 𝟳𝟮, essential, essay, esposito,
#
# Cluster 4:
# location, bac, middle, steal, signs, fucking, need, won, pitch, year,
#
# Cluster 5:
# row, starter, hits, batters, opening, day, astros, rt, essay, esposito,
#
# Cluster 6:
# going, long, year, astros, rt, season, espera, esposito, espn, espinosa,
#
# Cluster 7:
# training, spring, league, hilarious, hbps, graph, bar, end, shows, rt,
#
# Cluster 8:
# draft, mlb, round, 2019, university, selected, pick, selection, tigers, 2018,
#
# Cluster 9:
# baseball, best, today, rt, play, gods, time, gave, just, game,
#
# Cluster 10:
# team, draws, ch, kid, class, wins, starts, amp, season, world,
#
# Cluster 11:
# beanball, continues, tour, astros, rt, 𝟳𝟮, espinosa, est, essentially, essential,
#
# Cluster 12:
# road, game, spring, astros, rt, home, single, fans, year, 𝟳𝟮,
#
# Cluster 13:
# yankees, tonight, 05pm, vs, wfan, today, game, prior, roster, rhp,
#
# Cluster 14:
# opening, day, astros, rt, month, date, days, today, start, yankees,
#
# Cluster 15:
# season, allllllll, astros, going, long, rt, baseball, houston, 2020, fights,
#
# Cluster 16:
# ism, permanent, burns, mr, state, live, astros, rt, espinosa, essential,
#
# Cluster 17:
# god, work, doing, yankees, fans, rt, espinal, essay, esposito, espn,
#
# Cluster 18:
# tatsujin, taiko, 太鼓達人, taiwan, referring, arca, friend, lot, media, astros,
#
# Cluster 19:
# enhanced, audio, pitch, getting, hit, astros, rt, especially, espera, espero,
#
# Cluster 20:
# camp, training, astros, rt, espero, essential, essay, esposito, espn, espinosa,
#
# Cluster 21:
# heats, prepared, ex, ring, closer, scandal, cheating, world, series, astros,
#
# Cluster 22:
# unveil, irony, able, sign, 2017, world, series, astros, rt, esposito,
#
# Cluster 23:
# love, mic, baseball, players, mlb, game, astros, need, professional, just,
#
# Cluster 24:
# mlb, astros, day, just, rt, game, teams, got, ws, zero,
#
# Cluster 25:
# pm, school, live, high, vs, stream, mar, watch, 2020, 03,
#
# Cluster 26:
# fan, houston, astros, trolling, anytime, soon, rt, tv, end, shame,
#
# Cluster 27:
# series, world, yankees, dodgers, final, angels, champion, win, red, sox,

# %% [markdown]
# <a id="organize"></a>
# ## Capture and Organize User and Hashtag Information
# 1. Develop a method to capture user mention information. Users occurring together in general data (that is data you collected in part 1) as well as on the groups (result of part 2).
#   * You contrast between these two parts in terms of user interaction graph.
#   * Differentiate between different kinds of networks like retweet network; quote tweets etc.
#   * Provide information on data structure used.
# 2. Develop and describe a mechanism to capture hashtag information occurring together in general data as well as on the groups.
#   * Provide information on the data structure used.
# 3. Provide tabular data and contrast the data between various cases.

# %% [markdown]
# <a id="analysis"></a>
# ## Network Analysis
# 1. Analyse links ( path of 2) and Triads (closed loops) in all data (Part 1) and contrast with groups formed in part 2 above.
# 2. Explain the method to compute these motifs.
# 3. Provide statistics on your analysis (how many ties and triads)
